# %% [markdown]
# <img src='https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ-VfNtOyJbsaxu43Kztf_cv1mgBG6ZIQZEVw&usqp=CAU'>
#
# # Procesamiento de Lenguaje Natural
#
# ## Taller #5: TF-IDF
# `Fecha de entrega: Marzo 25, 2021. (Antes del inicio de la próxima clase).`
#
# `Modo de entrega: Subir link de GitHub al aula virtual.`

# %%
import re
import numpy as np
import pandas as pd

from nltk.corpus import stopwords
stopwords_sp = stopwords.words('spanish')

from nltk.stem.snowball import SnowballStemmer
spanishStemmer=SnowballStemmer("spanish")

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_distances

# %% [markdown]
# # Punto 1: Pre-Procesamiento
#
# - `[9 pts]` Leer el archivo `bob_esponja.csv` usando `pandas`
# - `[9 pts]` Crear una nueva columna con el texto en minúscula, sin caracteres especiales ni números, sin palabras vacias y hacer stemming de las palabras

# %%
tbl = pd.read_csv('C:/Users/johnv/bob_esponja.csv')
tbl
# Out:
#                           Personaje  \
# 0  Bob Esponja Pantalones Cuadrados
# 1                 Patricio Estrella
# 2              Calamardo Tentáculos
# 3                  Arenita Mejillas
# 4               Eugenio H. Cangrejo
# 5               Sheldon J. Plankton
# 6                    Karen Plankton
# 7                  Perlita Cangrejo
# 8                         Sra. Puff
# 9                   Gary el Caracol
#
#                                          Descripción
# 0  Bob Esponja es una esponja de mar con forma re...
# 1  Es una estrella de mar de color rosa, el mejor...
# 2  Calamardo Tentáculos es un personaje principal...
# 3  Arenita Mejillas (Sandy Cheeks en inglés) en u...
# 4  Don Eugenio H. Cangrejo (normalmente llamado S...
# 5  Sheldon J. Plankton, o simplemente Plankton, e...
# 6  Karen Plankton es uno de los dos principales a...
# 7  Perla "Perlita" Cangrejo es un personaje princ...
# 8  La Señora Puff es un personaje principal de Bo...
# 9  Gary el Caracol es un personaje principal de B...

# %%
def pre_procesado(texto):
    texto = texto.lower()
    texto = re.sub(r"[\W\d_]+"," ", texto)
    texto = [palabra for palabra in texto.split() if palabra not in stopwords_sp]
    texto = " ".join(texto)
    return texto

tbl['pre-procesado'] = tbl['Descripción'].apply(lambda texto: pre_procesado(texto))

tbl
# Out:
#                           Personaje  \
# 0  Bob Esponja Pantalones Cuadrados
# 1                 Patricio Estrella
# 2              Calamardo Tentáculos
# 3                  Arenita Mejillas
# 4               Eugenio H. Cangrejo
# 5               Sheldon J. Plankton
# 6                    Karen Plankton
# 7                  Perlita Cangrejo
# 8                         Sra. Puff
# 9                   Gary el Caracol
#
#                                          Descripción  \
# 0  Bob Esponja es una esponja de mar con forma re...
# 1  Es una estrella de mar de color rosa, el mejor...
# 2  Calamardo Tentáculos es un personaje principal...
# 3  Arenita Mejillas (Sandy Cheeks en inglés) en u...
# 4  Don Eugenio H. Cangrejo (normalmente llamado S...
# 5  Sheldon J. Plankton, o simplemente Plankton, e...
# 6  Karen Plankton es uno de los dos principales a...
# 7  Perla "Perlita" Cangrejo es un personaje princ...
# 8  La Señora Puff es un personaje principal de Bo...
# 9  Gary el Caracol es un personaje principal de B...
#
#                                        pre-procesado
# 0  bob esponja esponja mar forma rectangular colo...
# 1  estrella mar color rosa mejor amigo bob esponj...
# 2  calamardo tentáculos personaje principal bob e...
# 3  arenita mejillas sandy cheeks inglés personaje...
# 4  don eugenio h cangrejo normalmente llamado señ...
# 5  sheldon j plankton simplemente plankton dos an...
# 6  karen plankton dos principales antagonistas bo...
# 7  perla perlita cangrejo personaje principal bob...
# 8  señora puff personaje principal bob esponja ma...
# 9  gary caracol personaje principal bob esponja q...

# %% [markdown]
# # Punto 2: TF-IDF
#
# - `[16 pts]` Crear la matriz TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vect = TfidfVectorizer()
tfidf = tfidf_vect.fit_transform(tbl['pre-procesado'].values)

tfidf_matrix = pd.DataFrame(tfidf.toarray(), columns=tfidf_vect.get_feature_names())
tfidf_matrix.index = tbl['Personaje']

tfidf_matrix = tfidf_matrix.T.round(3)

tfidf_matrix
# Out:
# Personaje   Bob Esponja Pantalones Cuadrados  Patricio Estrella  \
# abajo                                  0.059                0.0
# aborrece                               0.000                0.0
# acaba                                  0.000                0.0
# accidente                              0.050                0.0
# aceptó                                 0.000                0.0
# ...                                      ...                ...
# zapatos                                0.044                0.0
# árbol                                  0.000                0.0
# éste                                   0.000                0.0
# única                                  0.059                0.0
# únicamente                             0.000                0.0
#
# Personaje   Calamardo Tentáculos  Arenita Mejillas  Eugenio H. Cangrejo  \
# abajo                      0.000             0.000                0.000
# aborrece                   0.091             0.000                0.000
# acaba                      0.091             0.000                0.000
# accidente                  0.000             0.000                0.046
# aceptó                     0.000             0.000                0.000
# ...                          ...               ...                  ...
# zapatos                    0.000             0.000                0.000
# árbol                      0.000             0.081                0.000
# éste                       0.000             0.000                0.000
# única                      0.000             0.000                0.000
# únicamente                 0.000             0.000                0.054
#
# Personaje   Sheldon J. Plankton  Karen Plankton  Perlita Cangrejo  Sra. Puff  \
# abajo                       0.0           0.000               0.0      0.000
# aborrece                    0.0           0.000               0.0      0.000
# acaba                       0.0           0.000               0.0      0.000
# accidente                   0.0           0.000               0.0      0.000
# aceptó                      0.0           0.064               0.0      0.000
# ...                         ...             ...               ...        ...
# zapatos                     0.0           0.000               0.0      0.092
# árbol                       0.0           0.000               0.0      0.000
# éste                        0.0           0.000               0.0      0.000
# única                       0.0           0.000               0.0      0.000
# únicamente                  0.0           0.000               0.0      0.000
#
# Personaje   Gary el Caracol
# abajo                 0.000
# aborrece              0.000
# acaba                 0.000
# accidente             0.000
# aceptó                0.000
# ...                     ...
# zapatos               0.069
# árbol                 0.000
# éste                  0.093
# única                 0.000
# únicamente            0.000
#
# [835 rows x 10 columns]

# %% [markdown]
# # Punto 3: Distancia del coseno
# - `[12 pts]` Calcular la distancia del coseno entre cada una de los personajes
# - `[2 pts]` ¿Cuáles son los personajes más parecidos?
# - `[2 pts]` ¿Cuáles son los personajes más diferentes?

# %%
from sklearn.metrics.pairwise import euclidean_distances

dist_euc = euclidean_distances(tfidf_matrix.T.values)
dist_euc = pd.DataFrame(dist_euc, columns = tfidf_matrix.columns, index=tfidf_matrix.columns)

#print(dist_euc)

from sklearn.metrics.pairwise import cosine_distances

dist_cos = cosine_distances(tfidf_matrix.T.values)
dist_cos = pd.DataFrame(dist_euc, columns = tfidf_matrix.columns, index = tfidf_matrix.columns)
dist_cos
# Out:
# Personaje                         Bob Esponja Pantalones Cuadrados  \
# Personaje
# Bob Esponja Pantalones Cuadrados                          0.000000
# Patricio Estrella                                         1.306876
# Calamardo Tentáculos                                      1.363981
# Arenita Mejillas                                          1.322932
# Eugenio H. Cangrejo                                       1.331643
# Sheldon J. Plankton                                       1.344001
# Karen Plankton                                            1.385879
# Perlita Cangrejo                                          1.353716
# Sra. Puff                                                 1.329562
# Gary el Caracol                                           1.366846
#
# Personaje                         Patricio Estrella  Calamardo Tentáculos  \
# Personaje
# Bob Esponja Pantalones Cuadrados           1.306876              1.363981
# Patricio Estrella                          0.000000              1.273918
# Calamardo Tentáculos                       1.273918              0.000000
# Arenita Mejillas                           1.338555              1.375782
# Eugenio H. Cangrejo                        1.340791              1.324977
# Sheldon J. Plankton                        1.392165              1.357684
# Karen Plankton                             1.388185              1.393436
# Perlita Cangrejo                           1.368362              1.394426
# Sra. Puff                                  1.382464              1.391864
# Gary el Caracol                            1.360384              1.354130
#
# Personaje                         Arenita Mejillas  Eugenio H. Cangrejo  \
# Personaje
# Bob Esponja Pantalones Cuadrados          1.322932             1.331643
# Patricio Estrella                         1.338555             1.340791
# Calamardo Tentáculos                      1.375782             1.324977
# Arenita Mejillas                          0.000000             1.365076
# Eugenio H. Cangrejo                       1.365076             0.000000
# Sheldon J. Plankton                       1.401727             1.189461
# Karen Plankton                            1.387689             1.347180
# Perlita Cangrejo                          1.401297             1.289353
# Sra. Puff                                 1.402471             1.371921
# Gary el Caracol                           1.365704             1.365973
#
# Personaje                         Sheldon J. Plankton  Karen Plankton  \
# Personaje
# Bob Esponja Pantalones Cuadrados             1.344001        1.385879
# Patricio Estrella                            1.392165        1.388185
# Calamardo Tentáculos                         1.357684        1.393436
# Arenita Mejillas                             1.401727        1.387689
# Eugenio H. Cangrejo                          1.189461        1.347180
# Sheldon J. Plankton                          0.000000        1.271247
# Karen Plankton                               1.271247        0.000000
# Perlita Cangrejo                             1.355802        1.401973
# Sra. Puff                                    1.406101        1.407884
# Gary el Caracol                              1.394105        1.399758
#
# Personaje                         Perlita Cangrejo  Sra. Puff  Gary el Caracol
# Personaje
# Bob Esponja Pantalones Cuadrados          1.353716   1.329562         1.366846
# Patricio Estrella                         1.368362   1.382464         1.360384
# Calamardo Tentáculos                      1.394426   1.391864         1.354130
# Arenita Mejillas                          1.401297   1.402471         1.365704
# Eugenio H. Cangrejo                       1.289353   1.371921         1.365973
# Sheldon J. Plankton                       1.355802   1.406101         1.394105
# Karen Plankton                            1.401973   1.407884         1.399758
# Perlita Cangrejo                          0.000000   1.336286         1.390702
# Sra. Puff                                 1.336286   0.000000         1.388392
# Gary el Caracol                           1.390702   1.388392         0.000000

# %% [markdown]
# # ¿Cuáles son los personajes más parecidos?

# %%
#Patricio y Bob esponja ya que su distancia es 1.30

# %% [markdown]
# # ¿Cuáles son los personajes más diferentes?

# %%
#Los mas diferentes son Karen Plankton y Bob Esponja ya que su distancia es 1.38
